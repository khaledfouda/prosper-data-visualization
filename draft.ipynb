# %%
import pandas as pd
from datetime import datetime
import numpy as np
import operator

# %%
data = pd.read_csv('./data/prosperLoanData.csv')

# %%
# extract the year from the date field, then make a new column with the year value
data.year = np.random.randn(len(data))

def getdate(row):
    try:
        row.ListingCreationDate = datetime.strptime(row['ListingCreationDate'],'%Y-%m-%d %H:%M:%S.%f000')
    except ValueError:
        row.ListingCreationDate = datetime.strptime(row['ListingCreationDate'],'%Y-%m-%d %H:%M:%S')
    year = row.ListingCreationDate.strftime('%Y')    
    row['year'] = int(year)
    row['BorrowerState'] = str( row['BorrowerState'] )
    return row

data = data.apply(getdate, axis=1)

# %%
## keep only the columns i'm interested in.
## list of columns to keep 
cols = [ 'MemberKey', 'Recommendations', 'year',
        'BorrowerState', 'Occupation', 'EmploymentStatus',
       'EmploymentStatusDuration', 'IsBorrowerHomeowner',
       'IncomeRange', 'IncomeVerifiable']

old_data = data
data = data[cols]

#sort data by MemberKey , then reset the index to count from 1 .. again after sorting.
data.sort_values('MemberKey',axis=0, inplace=1)
data.reset_index(drop=1,inplace=1)
# Out:
# /home/bekora/Documents/programming/Nanodegree/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#data.to_csv('./data/prosperLoanData_EDITED.csv',index=False)
#data.to_csv('./data/prosperLoanData_SAMPLE_EDITED.csv',index=False)

# %% [markdown]
# ---------

# %%
newData = data.groupby('MemberKey')

# %%
#23,106 Duplicates,  74,423 are not.
newData = data.duplicated('MemberKey',keep=False)
len(newData[ newData == True ])
data[~newData]
# Out:
#                       MemberKey  Recommendations  year BorrowerState  \
# 0       00003397697413387CAF966                1  2008            NC
# 1       000035297015484885C64F8                0  2011            FL
# 2       00013423961455492C1526A                0  2008            NY
# 3       000135288307754595F9D2F                0  2011            CA
# 4       00013697672720592A0D358                0  2013            NY
# 5       000234224617902327CDB8F                0  2008            UT
# 6       00023512368393241FC30E0                0  2011            CA
# 7       00023560572939500DCB8A0                0  2013            NY
# 8       000336932673742487C0D70                0  2013            CA
# 9       00043695776859528A2495F                0  2013            TX
# 10      000533807507582640364CD                0  2007            AL
# 11      000535754154222966B31E3                0  2014            VA
# 12      00063381446480331D5115B                0  2007            IL
# 13      000635435814413083EACE3                0  2013            NJ
# 14      00063700478721718A1DC44                0  2013            MO
# 15      0007338998629653405FDD0                0  2007            TX
# 16      000735524117406723E4DE9                0  2012            CA
# 17      000A3536565603221E71FA5                0  2012            MD
# 18      000B3485235890531DB74A3                0  2010            NY
# 22      000C3562664704659E67FC1                0  2012            FL
# 23      000D3364744191925B20840                0  2006            FL
# 24      000D3475854555891279899                0  2010            TX
# 25      000E35533262890553D3AAA                0  2012            NC
# 26      000E3577493871327A5394D                0  2013            CO
# 27      001034911007416607A663B                0  2010            CA
# 28      00103561547411388E90630                0  2012            CA
# 29      0010356483845050893B702                0  2012            FL
# 30      00103707385748594203705                0  2014            NY
# 31      00113574311629669B4DB9E                0  2013            CA
# 32      0011370687712925366D380                0  2014            TX
# ...                         ...              ...   ...           ...
# 113879  FFE235745100863216DA7D5                0  2013            NY
# 113880  FFE23577521291208BA9EBC                0  2013            CA
# 113881  FFE435555769685208B46A3                0  2012            FL
# 113884  FFE5357753755751641EBBA                0  2013            CA
# 113885  FFE6338626322998665A23F                0  2007            MI
# 113886  FFE63396445400105EB6E0A                1  2007            MO
# 113887  FFE63537356091511C9469F                0  2012            MN
# 113890  FFEA3699973813492AE59C0                0  2013            NY
# 113891  FFEC37070173023742D2580                0  2014            PA
# 113892  FFED33686061625063C9F8A                0  2006            TX
# 113893  FFED34048927851237DCDB0                0  2007            MD
# 113894  FFED37015271215068BB307                0  2013            GA
# 113895  FFEE35854294897087C0324                0  2013            NY
# 113901  FFEF369300586255623A40C                0  2013            KS
# 113902  FFEF37049093579583EE4B0                0  2014            NC
# 113903  FFF03365189029709AB822E                0  2007           NaN
# 113907  FFF135753399890944E4A52                0  2014            AZ
# 113908  FFF3355649076790505B993                0  2012            WA
# 113909  FFF33700152692892F3E9C2                0  2013            CA
# 113910  FFF436993927986256BF9D8                0  2013            AR
# 113911  FFF5354507429612058EECD                0  2012            TN
# 113912  FFF633657849233430E7BB4                0  2006            GA
# 113917  FFF83545504539670FD8A03                0  2012            MD
# 113918  FFF835831698956324BBFE6                0  2013            WA
# 113926  FFF9369988761425816004D                0  2013            FL
# 113927  FFFB35532659344392FF450                0  2012            WI
# 113928  FFFB3573181023089B6272C                0  2013            AL
# 113929  FFFC33656143739582B0E90                0  2008            CA
# 113933  FFFD3693387788778FDB6D8                0  2013            MI
# 113934  FFFE37064763028757082B0                0  2014            VA
#
#                       Occupation EmploymentStatus  EmploymentStatusDuration  \
# 0                          Other    Self-employed                      33.0
# 1                          Other    Self-employed                      77.0
# 2                  Skilled Labor        Full-time                     178.0
# 3                       Investor    Self-employed                     157.0
# 4                     Nurse (RN)         Employed                      45.0
# 5                          Other        Full-time                      22.0
# 6                   Professional         Employed                       6.0
# 7            Computer Programmer         Employed                     182.0
# 8                     Car Dealer         Employed                     147.0
# 9                     Nurse (RN)         Employed                      52.0
# 10                Accountant/CPA        Full-time                      70.0
# 11       Food Service Management         Employed                      12.0
# 12         Engineer - Electrical        Full-time                     297.0
# 13                Accountant/CPA         Employed                      54.0
# 14                 Skilled Labor         Employed                      56.0
# 15                   Nurse (LPN)        Full-time                      78.0
# 16                       Teacher         Employed                     251.0
# 17          Tradesman - Mechanic         Employed                      25.0
# 18                  Professional        Full-time                      34.0
# 22                         Other         Employed                      19.0
# 23                 Civil Service    Not available                       NaN
# 24       Food Service Management        Full-time                      38.0
# 25                         Other         Employed                      92.0
# 26                  Construction         Employed                      48.0
# 27                         Other            Other                      42.0
# 28      Administrative Assistant         Employed                       0.0
# 29                  Food Service         Employed                     299.0
# 30                        Doctor         Employed                      90.0
# 31                         Other    Self-employed                      24.0
# 32           Computer Programmer         Employed                     177.0
# ...                          ...              ...                       ...
# 113879                     Other            Other                      83.0
# 113880                   Teacher         Employed                      57.0
# 113881                   Dentist         Employed                       1.0
# 113884                  Attorney         Employed                       4.0
# 113885              Truck Driver        Full-time                     216.0
# 113886         Retail Management        Full-time                      31.0
# 113887            Sales - Retail         Employed                      62.0
# 113890             Civil Service         Employed                     166.0
# 113891     Engineer - Mechanical         Employed                      87.0
# 113892                   Analyst    Not available                       NaN
# 113893        Sales - Commission        Full-time                       9.0
# 113894                   Teacher         Employed                      52.0
# 113895                     Other     Not employed                       3.0
# 113901                     Other         Employed                      18.0
# 113902        Sales - Commission         Employed                      16.0
# 113903        Medical Technician    Not available                       NaN
# 113907                    Doctor         Employed                      15.0
# 113908             Civil Service         Employed                      16.0
# 113909  Administrative Assistant         Employed                      52.0
# 113910              Professional         Employed                      13.0
# 113911     Engineer - Electrical         Employed                       6.0
# 113912       Computer Programmer    Not available                       NaN
# 113917              Professional         Employed                     105.0
# 113918              Professional         Employed                     339.0
# 113926              Nurse's Aide         Employed                      63.0
# 113927        Sales - Commission         Employed                     286.0
# 113928                     Other         Employed                     194.0
# 113929       Computer Programmer    Self-employed                      77.0
# 113933             Skilled Labor         Employed                     172.0
# 113934                   Analyst         Employed                       8.0
#
#        IsBorrowerHomeowner     IncomeRange IncomeVerifiable
# 0                    False              $0            False
# 1                    False  $75,000-99,999            False
# 2                     True  $50,000-74,999             True
# 3                    False  $50,000-74,999            False
# 4                     True       $100,000+             True
# 5                     True  $50,000-74,999             True
# 6                    False       $100,000+             True
# 7                     True       $100,000+             True
# 8                    False  $50,000-74,999             True
# 9                    False  $75,000-99,999             True
# 10                   False  $25,000-49,999             True
# 11                   False  $25,000-49,999             True
# 12                    True       $100,000+             True
# 13                   False  $50,000-74,999             True
# 14                    True  $25,000-49,999             True
# 15                    True  $25,000-49,999             True
# 16                   False  $75,000-99,999             True
# 17                   False  $25,000-49,999             True
# 18                   False  $50,000-74,999             True
# 22                   False  $25,000-49,999             True
# 23                    True   Not displayed             True
# 24                    True  $50,000-74,999             True
# 25                   False  $25,000-49,999             True
# 26                   False  $50,000-74,999             True
# 27                   False       $1-24,999             True
# 28                   False  $25,000-49,999            False
# 29                    True       $100,000+             True
# 30                    True       $100,000+             True
# 31                   False  $50,000-74,999            False
# 32                    True       $100,000+             True
# ...                    ...             ...              ...
# 113879                True       $1-24,999             True
# 113880                True  $50,000-74,999             True
# 113881                True  $25,000-49,999             True
# 113884                True       $100,000+             True
# 113885                True  $50,000-74,999             True
# 113886               False  $25,000-49,999             True
# 113887               False       $1-24,999             True
# 113890               False  $75,000-99,999             True
# 113891               False  $50,000-74,999             True
# 113892                True   Not displayed             True
# 113893               False  $25,000-49,999             True
# 113894                True  $25,000-49,999             True
# 113895               False    Not employed            False
# 113901                True  $25,000-49,999             True
# 113902                True       $100,000+             True
# 113903               False   Not displayed             True
# 113907                True       $100,000+             True
# 113908                True  $50,000-74,999             True
# 113909               False       $100,000+             True
# 113910                True  $25,000-49,999             True
# 113911               False  $75,000-99,999             True
# 113912                True   Not displayed             True
# 113917               False  $75,000-99,999             True
# 113918                True  $75,000-99,999             True
# 113926               False  $25,000-49,999             True
# 113927                True  $50,000-74,999             True
# 113928                True  $50,000-74,999             True
# 113929                True              $0            False
# 113933                True  $50,000-74,999             True
# 113934                True       $100,000+             True
#
# [74423 rows x 10 columns]

# %% [markdown]
# ----
#
# ### MAKE A DICTIONARY FOR  BORROWER STATES.

# %%
data = pd.read_csv('./data/prosperLoanData_EDITED.csv')

# %%
states = {}
for state in data.BorrowerState :
    if str(state) in states.keys() :
        states[str(state)] +=1
    else :
        states[str(state)] = 1
#print the states sorted.        
sorted(states.items(), key=operator.itemgetter(1),reverse=True)
# Out:
# [('CA', 14717),
#  ('TX', 6842),
#  ('NY', 6729),
#  ('FL', 6720),
#  ('IL', 5921),
#  ('nan', 5515),
#  ('GA', 5008),
#  ('OH', 4197),
#  ('MI', 3593),
#  ('VA', 3278),
#  ('NJ', 3097),
#  ('NC', 3084),
#  ('WA', 3048),
#  ('PA', 2972),
#  ('MD', 2821),
#  ('MO', 2615),
#  ('MN', 2318),
#  ('MA', 2242),
#  ('CO', 2210),
#  ('IN', 2078),
#  ('AZ', 1901),
#  ('WI', 1842),
#  ('OR', 1817),
#  ('TN', 1737),
#  ('AL', 1679),
#  ('CT', 1627),
#  ('SC', 1122),
#  ('NV', 1090),
#  ('KS', 1062),
#  ('KY', 983),
#  ('OK', 971),
#  ('LA', 954),
#  ('UT', 877),
#  ('AR', 855),
#  ('MS', 787),
#  ('NE', 674),
#  ('ID', 599),
#  ('NH', 551),
#  ('NM', 472),
#  ('RI', 435),
#  ('HI', 409),
#  ('WV', 391),
#  ('DC', 382),
#  ('MT', 330),
#  ('DE', 300),
#  ('VT', 207),
#  ('AK', 200),
#  ('SD', 189),
#  ('IA', 186),
#  ('WY', 150),
#  ('ME', 101),
#  ('ND', 52)]

# %%
# read states names, this includes statename All in capital, state name first litter is capital,
# and 2 letters representing the state
# As  [state1,state2,short]
states_names = pd.read_csv('./data/map/us_states_names.csv')

# %%
# make a new dictionary, similar to states{} but instead of the 2 letters, it will have the whole state name.
new_states = {}
for state in states.keys() :
    for state_short,state_long in zip(states_names.short,states_names.name2) :
        if state == state_short :
            new_states[state_long] = states[state]
            break   
new_states['nan'] = states['nan']       # add the nan values.     
new_states['Washington'] += states['DC']   # Washington has two short names "WA" and "DC".

# %%
# write the dictionary (new_states) into a csv file.
with open('data/map/borrower_states.csv', 'wb') as f :
    f.write('state,count\n')
    for item in new_states.items():
        f.write(item[0]+","+str(item[1])+'\n')

# %% [markdown]
# ---------------

# %%
sorted(new_states.items(), key=operator.itemgetter(1),reverse=True)
# Out:
# [('California', 14717),
#  ('Texas', 6842),
#  ('New York', 6729),
#  ('Florida', 6720),
#  ('Illinois', 5921),
#  ('nan', 5515),
#  ('Georgia', 5008),
#  ('Ohio', 4197),
#  ('Michigan', 3593),
#  ('Washington', 3430),
#  ('Virginia', 3278),
#  ('New Jersey', 3097),
#  ('North Carolina', 3084),
#  ('Pennsylvania', 2972),
#  ('Maryland', 2821),
#  ('Missouri', 2615),
#  ('Minnesota', 2318),
#  ('Massachusetts', 2242),
#  ('Colorado', 2210),
#  ('Indiana', 2078),
#  ('Arizona', 1901),
#  ('Wisconsin', 1842),
#  ('Oregon', 1817),
#  ('Tennessee', 1737),
#  ('Alabama', 1679),
#  ('Connecticut', 1627),
#  ('South Carolina', 1122),
#  ('Nevada', 1090),
#  ('Kansas', 1062),
#  ('Kentucky', 983),
#  ('Oklahoma', 971),
#  ('Louisiana', 954),
#  ('Utah', 877),
#  ('Arkansas', 855),
#  ('Mississippi', 787),
#  ('Nebraska', 674),
#  ('Idaho', 599),
#  ('New Hampshire', 551),
#  ('New Mexico', 472),
#  ('Rhode Island', 435),
#  ('Hawaii', 409),
#  ('West Virginia', 391),
#  ('Montana', 330),
#  ('Delaware', 300),
#  ('Vermont', 207),
#  ('Alaska', 200),
#  ('South Dakota', 189),
#  ('Iowa', 186),
#  ('Wyoming', 150),
#  ('Maine', 101),
#  ('North Dakota', 52)]
